# %%
import pandas as pd
path="compliance_benchmark.csv"
df=pd.read_csv(path)
df
# Out:
#                                              question  \
# 0   Under Management's Annual Report on Internal C...
# 1   Under what circumstance does the confidentiali...
# 2   What technological and supplier-driven factors...
# 3   Under what condition and through what specific...
# 4   Under the regulatory provisions for Video-base...
# ..                                                ...
# 95  What are the standard minimum frequencies for ...
# 96  What mandatory reporting obligation is imposed...
# 97  Based on the filing status and compliance disc...
# 98  Based on amendment reference citations 28, 29,...
# 99  Which exhibit related to the 2022 Employee Sto...
#
#                                          ground_truth  \
# 0   Management evaluated the effectiveness of inte...
# 1   The confidentiality requirement does not inhib...
# 2   The factors include: (1) initial capacity cons...
# 3   A customer's PAN details must be verified from...
# ...

# %%
df2=pd.read_csv("final_evaluation_report.csv")

# %%
df2
# Out:
#                                            user_input  \
# 0   Under Management's Annual Report on Internal C...
# 1   Under what circumstance does the confidentiali...
# 2   What technological and supplier-driven factors...
# 3   Under what condition and through what specific...
# 4   Under the regulatory provisions for Video-base...
# ..                                                ...
# 95  What are the standard minimum frequencies for ...
# 96  What mandatory reporting obligation is imposed...
# 97  Based on the filing status and compliance disc...
# 98  Based on amendment reference citations 28, 29,...
# 99  Which exhibit related to the 2022 Employee Sto...
#
#                                    retrieved_contexts  \
# 0   ["Management's Annual Report on Internal Contr...
# 1   ['Every RE, its directors, officers, and all e...
# 2   ["Additionally, the Company's new products oft...
# 3   ["- i. No change in KYC information: In case o...
# ...
