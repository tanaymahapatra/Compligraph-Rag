# %%
import pandas as pd
p="compliance_benchmark.csv"
df=pd.read_csv(p)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 p="/Users/tanay/Desktop/Multi-Agent Financial Copilot/data/compliance_benchmark.csv"
# ----> 3 df=pd.read_csv(p)
#       4 df
#
# File ~/Desktop/Compligraph-Rag/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
d=pd.read_csv("data/final_evaluation_report.csv")

# %%
d
# Out:
#                                            user_input  \
# 0   According to the 1999 working paper authored b...
# 1   How do the costs of fire sales of assets in ma...
# 2   Under the capital requirements suggested under...
# 3   Under table-7.2.12, how does the projected imp...
# 4   What table identifier and subject heading are ...
# 5   Under what specific regulatory provision of Re...
# 6   If a wire transfer's ordering financial instit...
# 7   Based on the provided financial statement data...
# 8   How is Systemic Risk described in relation to ...
# 9   Which regulatory circular containing the code ...
# 10  For Senior Management (such as Whole Time Dire...
# 11  Based on the regulatory filing excerpt for App...
# 12  In 2025, how did the portion of the Company's ...
# 13  Under the section labeled 'G83G99G101G110G97G1...
# 14  Under the model assumptions where the cost of ...
# 15  Based on the author's calculations table, what...
# ...
